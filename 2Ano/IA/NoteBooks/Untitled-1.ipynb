# %% [markdown]
# ## 1º AULA - Tutorial Pandas para Machine Learning: Dataset IRIS
#
# # Carregar o Pnadas e o dataset IRIS

# %%
# %pwd
# Out:
# '/Users/emanuelgomes/Desktop/ESMAD/GitHub 2/ESMAD/2Ano/IA/NoteBooks'

# %%
import pandas as pd
import numpy as np

## 1. Carregamento de dados 
##  Vamos carregar o dataset IRIS diretamente de um repositorio online
##  url = 
##  de = pd.read_csv(url)
##
